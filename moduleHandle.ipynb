# %%
from pythonIntroduction import myFntn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from pythonIntroduction import myFntn
#
# ModuleNotFoundError: No module named 'pythonIntroduction'
